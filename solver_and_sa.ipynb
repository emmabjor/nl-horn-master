# %% [markdown]
# # Inconsistency checker and sentiment analysis
#
# This ipynb file contain the code for creating an inconsistency checker program and a sentiment analysis model.

# %% [markdown]
# ## Inconsistency checker
#
# By running the following cell, all valid Horn clause formulas form the file ``encoding-results.tsv`` will be converted to ASP facts and rules. All rules and facts from the NL dataset are saved in ``results/horn_inconsistency_checker.lp``. The function find_min_set will isolate all conflicting norms.

# %%
import pandas as pd
import re
import copy
from itertools import permutations
import json
import clingo


df = pd.read_csv('results/encoding-results.tsv', header=0, sep='\t')
valid_fol_df = df[df["horn-eval"]==1]
edit = valid_fol_df[valid_fol_df.num != 1107] # remove juvenile case
valid_horn = edit["horn"]

def strip_parenthesis(s):
    try:
        while s[0] == '(':
            s = s[1:]
        if s.count('(') == s.count(')'):
            return s
        while s[-2] == ')':
            s = s[:-1]
        return s
    except IndexError:
        return s
    

def pred_eval(horn):
    
    predsplit = (re.split("∨|∧", horn))
    eval = ""
    remove = ""
    for i in range(len(predsplit)):
        horn_edit = strip_parenthesis(predsplit[i].strip())
        if "evaluation(BAD)" in horn_edit:
            eval = "bad"
            remove = predsplit[i]
        elif "evaluation(GOOD)" in horn_edit:
            eval = "good"
            remove = predsplit[i]
        else:
            predsplit[i] = (horn_edit.strip())
    predsplit.remove(remove)
    return [eval, predsplit]


def change_syntax(horn):

    p_norm = pred_eval(horn)
    p_rule = copy.deepcopy(p_norm)
    for i in range(len(p_rule[1])):

        p_rule[1][i] = p_rule[1][i].replace("¬", "-")
        p_rule[1][i] = p_rule[1][i].lower()
        p_rule[1][i] = re.sub(r'(v)(\d+)', r'V\2', p_rule[1][i])

    
    for i in range(len(p_norm[1])):
        p_norm[1][i] = p_norm[1][i].replace("¬", "-")
        p_norm[1][i] = p_norm[1][i].lower()

    return p_rule, p_norm

prolog_dict = {}

def create_norm(p_norm):
    perm = list(permutations(p_norm[1]))

    norm = str(len(perm))+"{"
    for p in perm:
        if len(perm) == 1:
            p = str(p)
            p = p[:-2] + p[-1:]
        part = "rule("+str(p_norm[0])+","+str(p)
        norm += part.replace("'", "")+"); "
    return norm[:-2]+"}"+str(len(perm))+"."

def create_rule(p_rule):
    rule = ":- rule(good,("
    for p in p_rule[1]:
        rule += str(p)+", "
    rule = rule[:-2]
    rule += ")), rule(bad,("
    for p in p_rule[1]:
        r = re.sub(r'(V)(\d+)', r'W\2', p)
        rule += str(r)+", "
    return rule[:-2] + "))."

prolog_dict = {}
valid_horn = list(valid_horn)

for horn in valid_horn:
    if "∧" in horn: # don't know how to solve this yet
        continue
    p_rule, p_norm = change_syntax(horn)
    norm = (create_norm(p_norm))
    rule = (create_rule(p_rule))
    prolog_dict[horn] = [norm, rule]
    
# Load the JSON data into a Python dictionary
#data = json.loads(prolog_dict)

# Prepare the content for the clingo file
clingo_content = ""

for norm, rule in prolog_dict.items():
    clingo_content += f"% {norm}\n" + "\n".join(rule) + "\n%---CLAUSE---\n"

# Show the prepared content
# print(clingo_content)

# # Save the content to a clingo file
# with open("horn_inconsistency_checker.lp", "w") as file:
#     file.write(clingo_content)

# %%
min_set = ""

def find_min_set(content):
    global min_set
    rest = ""
    clt = clingo.Control()
    clt.add("base", [], content)
    clt.ground([("base", [])])
    result = clt.solve()
    while result.satisfiable == False:
        current = content[:content.find('%---CLAUSE---')]
        content = content[content.find('%---CLAUSE---')+14:]
        clt = clingo.Control()
        clt.add("base", [], content)
        clt.ground([("base", [])])
        res = clt.solve()
        if res.satisfiable == True:
            min_set += '---------------------------\n'+current+'%---CLAUSE---\n'
            clt = clingo.Control()
            clt.add("base", [], content)
            clt.ground([("base", [])])
            result = clt.solve()
            clt = clingo.Control()
            clt.add("base", [], current)
            clt.ground([("base", [])])
            single = clt.solve()
            if single.satisfiable == True:
                for clause in content.split('%---CLAUSE---'):
                    test = current+ '\n'+clause
                    clt = clingo.Control()
                    clt.add("base", [], test)
                    clt.ground([("base", [])])
                    res1 = clt.solve()
                    if res1.satisfiable == False:
                        min_set += clause+'%---CLAUSE---\n'
                        content = content.replace(clause,'')
                min_set+='---------------------------'
        else:
            rest += current+'%---CLAUSE---\n'
    rest += content
    clt = clingo.Control()
    clt.add("base", [], rest)
    clt.ground([("base", [])])
    final = clt.solve()   
    if final.satisfiable == False:
        find_min_set(rest)
    return min_set



sett = find_min_set(clingo_content)
# Out:
# <block>:2778:13-16: info: operation undefined:
#   (-co)
#
# <block>:2778:105-108: info: operation undefined:
#   (-co)
#
# <block>:2778:221-224: info: operation undefined:
#   (-co)
#
# <block>:2778:343-346: info: operation undefined:
#   (-co)
#
# <block>:2778:411-414: info: operation undefined:
#   (-co)
#
# <block>:2778:527-530: info: operation undefined:
#   (-co)
#
# <block>:2779:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:4-56: info: atom does not occur in any rule head:
#   rule(good,((-familyof(V4,V3)),(-askstoomuch(V3,V4))))
#
# <block>:7:74-141: info: atom does not occur in any rule head:
#   rule(bad,((-goesshopping(W5)),(-people(W6)),(-new(W6)),(-meet(W5,W6))))
#
# <block>:11:80-153: info: atom does not occur in any rule head:
#   rule(bad,((-firstpaycheck(W8)),(-belongsto(W8,W7)),(-excitedabout(W7,W8))))
#
# <block>:15:71-135: info: atom does not occur in any rule head:
#   rule(bad,((-safetoeat(W11)),(-servesto(W9,W10,W11)),(-food(W11))))
#
# <block>:19:4-73: info: atom does not occur in any rule head:
#   rule(good,((-sees(V12,V13)),(-advantageinlife(V13)),(-takes(V12,V13))))
#
# <block>:23:4-92: info: atom does not occur in any rule head:
#   rule(good,((-friends(V14,V15)),(-hassignificantother(V15,V16)),(-triestosteal(V14,V16))))
#
# <block>:27:4-84: info: atom does not occur in any rule head:
#   rule(good,((-wantstolearn(V19,drive)),(-freedrivinglesson(V20)),(-gets(V19,V20))))
#
# <block>:31:4-35: info: atom does not occur in any rule head:
#   rule(good,(-livesin(V21,van)))
#
# <block>:35:56-105: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W23,W22)),(-loves(W22,W23))))
#
# <block>:39:75-143: info: atom does not occur in any rule head:
#   rule(bad,((-takecareof(W24,W24)),(-nicething(W25)),(-dofor(W24,W25))))
#
# <block>:43:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:47:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:51:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:2774:13-16: info: operation undefined:
#   (-co)
#
# <block>:2774:105-108: info: operation undefined:
#   (-co)
#
# <block>:2774:221-224: info: operation undefined:
#   (-co)
#
# <block>:2774:343-346: info: operation undefined:
#   (-co)
#
# <block>:2774:411-414: info: operation undefined:
#   (-co)
#
# <block>:2774:527-530: info: operation undefined:
#   (-co)
#
# <block>:2775:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:74-141: info: atom does not occur in any rule head:
#   rule(bad,((-goesshopping(W5)),(-people(W6)),(-new(W6)),(-meet(W5,W6))))
#
# <block>:7:80-153: info: atom does not occur in any rule head:
#   rule(bad,((-firstpaycheck(W8)),(-belongsto(W8,W7)),(-excitedabout(W7,W8))))
#
# <block>:11:71-135: info: atom does not occur in any rule head:
#   rule(bad,((-safetoeat(W11)),(-servesto(W9,W10,W11)),(-food(W11))))
#
# <block>:15:4-73: info: atom does not occur in any rule head:
#   rule(good,((-sees(V12,V13)),(-advantageinlife(V13)),(-takes(V12,V13))))
#
# <block>:19:4-92: info: atom does not occur in any rule head:
#   rule(good,((-friends(V14,V15)),(-hassignificantother(V15,V16)),(-triestosteal(V14,V16))))
#
# <block>:23:4-84: info: atom does not occur in any rule head:
#   rule(good,((-wantstolearn(V19,drive)),(-freedrivinglesson(V20)),(-gets(V19,V20))))
#
# <block>:27:4-35: info: atom does not occur in any rule head:
#   rule(good,(-livesin(V21,van)))
#
# <block>:31:56-105: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W23,W22)),(-loves(W22,W23))))
#
# <block>:35:75-143: info: atom does not occur in any rule head:
#   rule(bad,((-takecareof(W24,W24)),(-nicething(W25)),(-dofor(W24,W25))))
#
# <block>:39:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:43:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:47:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:51:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:2770:13-16: info: operation undefined:
#   (-co)
#
# <block>:2770:105-108: info: operation undefined:
#   (-co)
#
# <block>:2770:221-224: info: operation undefined:
#   (-co)
#
# <block>:2770:343-346: info: operation undefined:
#   (-co)
#
# <block>:2770:411-414: info: operation undefined:
#   (-co)
#
# <block>:2770:527-530: info: operation undefined:
#   (-co)
#
# <block>:2771:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:80-153: info: atom does not occur in any rule head:
#   rule(bad,((-firstpaycheck(W8)),(-belongsto(W8,W7)),(-excitedabout(W7,W8))))
#
# <block>:7:71-135: info: atom does not occur in any rule head:
#   rule(bad,((-safetoeat(W11)),(-servesto(W9,W10,W11)),(-food(W11))))
#
# <block>:11:4-73: info: atom does not occur in any rule head:
#   rule(good,((-sees(V12,V13)),(-advantageinlife(V13)),(-takes(V12,V13))))
#
# <block>:15:4-92: info: atom does not occur in any rule head:
#   rule(good,((-friends(V14,V15)),(-hassignificantother(V15,V16)),(-triestosteal(V14,V16))))
#
# <block>:19:4-84: info: atom does not occur in any rule head:
#   rule(good,((-wantstolearn(V19,drive)),(-freedrivinglesson(V20)),(-gets(V19,V20))))
#
# <block>:23:4-35: info: atom does not occur in any rule head:
#   rule(good,(-livesin(V21,van)))
#
# <block>:27:56-105: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W23,W22)),(-loves(W22,W23))))
#
# <block>:31:75-143: info: atom does not occur in any rule head:
#   rule(bad,((-takecareof(W24,W24)),(-nicething(W25)),(-dofor(W24,W25))))
#
# <block>:35:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:39:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:43:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:47:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:51:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:2766:13-16: info: operation undefined:
#   (-co)
#
# <block>:2766:105-108: info: operation undefined:
#   (-co)
#
# <block>:2766:221-224: info: operation undefined:
#   (-co)
#
# <block>:2766:343-346: info: operation undefined:
#   (-co)
#
# <block>:2766:411-414: info: operation undefined:
#   (-co)
#
# <block>:2766:527-530: info: operation undefined:
#   (-co)
#
# <block>:2767:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:71-135: info: atom does not occur in any rule head:
#   rule(bad,((-safetoeat(W11)),(-servesto(W9,W10,W11)),(-food(W11))))
#
# <block>:7:4-73: info: atom does not occur in any rule head:
#   rule(good,((-sees(V12,V13)),(-advantageinlife(V13)),(-takes(V12,V13))))
#
# <block>:11:4-92: info: atom does not occur in any rule head:
#   rule(good,((-friends(V14,V15)),(-hassignificantother(V15,V16)),(-triestosteal(V14,V16))))
#
# <block>:15:4-84: info: atom does not occur in any rule head:
#   rule(good,((-wantstolearn(V19,drive)),(-freedrivinglesson(V20)),(-gets(V19,V20))))
#
# <block>:19:4-35: info: atom does not occur in any rule head:
#   rule(good,(-livesin(V21,van)))
#
# <block>:23:56-105: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W23,W22)),(-loves(W22,W23))))
#
# <block>:27:75-143: info: atom does not occur in any rule head:
#   rule(bad,((-takecareof(W24,W24)),(-nicething(W25)),(-dofor(W24,W25))))
#
# <block>:31:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:35:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:39:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:43:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:47:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:51:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:2762:13-16: info: operation undefined:
#   (-co)
#
# <block>:2762:105-108: info: operation undefined:
#   (-co)
#
# <block>:2762:221-224: info: operation undefined:
#   (-co)
#
# <block>:2762:343-346: info: operation undefined:
#   (-co)
#
# <block>:2762:411-414: info: operation undefined:
#   (-co)
#
# <block>:2762:527-530: info: operation undefined:
#   (-co)
#
# <block>:2763:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:4-73: info: atom does not occur in any rule head:
#   rule(good,((-sees(V12,V13)),(-advantageinlife(V13)),(-takes(V12,V13))))
#
# <block>:7:4-92: info: atom does not occur in any rule head:
#   rule(good,((-friends(V14,V15)),(-hassignificantother(V15,V16)),(-triestosteal(V14,V16))))
#
# <block>:11:4-84: info: atom does not occur in any rule head:
#   rule(good,((-wantstolearn(V19,drive)),(-freedrivinglesson(V20)),(-gets(V19,V20))))
#
# <block>:15:4-35: info: atom does not occur in any rule head:
#   rule(good,(-livesin(V21,van)))
#
# <block>:19:56-105: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W23,W22)),(-loves(W22,W23))))
#
# <block>:23:75-143: info: atom does not occur in any rule head:
#   rule(bad,((-takecareof(W24,W24)),(-nicething(W25)),(-dofor(W24,W25))))
#
# <block>:27:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:31:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:35:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:39:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:43:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:47:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:51:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:2758:13-16: info: operation undefined:
#   (-co)
#
# <block>:2758:105-108: info: operation undefined:
#   (-co)
#
# <block>:2758:221-224: info: operation undefined:
#   (-co)
#
# <block>:2758:343-346: info: operation undefined:
#   (-co)
#
# <block>:2758:411-414: info: operation undefined:
#   (-co)
#
# <block>:2758:527-530: info: operation undefined:
#   (-co)
#
# <block>:2759:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:4-92: info: atom does not occur in any rule head:
#   rule(good,((-friends(V14,V15)),(-hassignificantother(V15,V16)),(-triestosteal(V14,V16))))
#
# <block>:7:4-84: info: atom does not occur in any rule head:
#   rule(good,((-wantstolearn(V19,drive)),(-freedrivinglesson(V20)),(-gets(V19,V20))))
#
# <block>:11:4-35: info: atom does not occur in any rule head:
#   rule(good,(-livesin(V21,van)))
#
# <block>:15:56-105: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W23,W22)),(-loves(W22,W23))))
#
# <block>:19:75-143: info: atom does not occur in any rule head:
#   rule(bad,((-takecareof(W24,W24)),(-nicething(W25)),(-dofor(W24,W25))))
#
# <block>:23:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:27:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:31:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:35:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:39:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:43:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:47:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:51:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:2754:13-16: info: operation undefined:
#   (-co)
#
# <block>:2754:105-108: info: operation undefined:
#   (-co)
#
# <block>:2754:221-224: info: operation undefined:
#   (-co)
#
# <block>:2754:343-346: info: operation undefined:
#   (-co)
#
# <block>:2754:411-414: info: operation undefined:
#   (-co)
#
# <block>:2754:527-530: info: operation undefined:
#   (-co)
#
# <block>:2755:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:4-84: info: atom does not occur in any rule head:
#   rule(good,((-wantstolearn(V19,drive)),(-freedrivinglesson(V20)),(-gets(V19,V20))))
#
# <block>:7:4-35: info: atom does not occur in any rule head:
#   rule(good,(-livesin(V21,van)))
#
# <block>:11:56-105: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W23,W22)),(-loves(W22,W23))))
#
# <block>:15:75-143: info: atom does not occur in any rule head:
#   rule(bad,((-takecareof(W24,W24)),(-nicething(W25)),(-dofor(W24,W25))))
#
# <block>:19:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:23:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:27:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:31:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:35:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:39:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:43:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:47:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:51:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:2750:13-16: info: operation undefined:
#   (-co)
#
# <block>:2750:105-108: info: operation undefined:
#   (-co)
#
# <block>:2750:221-224: info: operation undefined:
#   (-co)
#
# <block>:2750:343-346: info: operation undefined:
#   (-co)
#
# <block>:2750:411-414: info: operation undefined:
#   (-co)
#
# <block>:2750:527-530: info: operation undefined:
#   (-co)
#
# <block>:2751:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:4-35: info: atom does not occur in any rule head:
#   rule(good,(-livesin(V21,van)))
#
# <block>:7:56-105: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W23,W22)),(-loves(W22,W23))))
#
# <block>:11:75-143: info: atom does not occur in any rule head:
#   rule(bad,((-takecareof(W24,W24)),(-nicething(W25)),(-dofor(W24,W25))))
#
# <block>:15:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:19:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:23:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:27:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:31:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:35:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:39:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:43:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:47:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:51:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:2746:13-16: info: operation undefined:
#   (-co)
#
# <block>:2746:105-108: info: operation undefined:
#   (-co)
#
# <block>:2746:221-224: info: operation undefined:
#   (-co)
#
# <block>:2746:343-346: info: operation undefined:
#   (-co)
#
# <block>:2746:411-414: info: operation undefined:
#   (-co)
#
# <block>:2746:527-530: info: operation undefined:
#   (-co)
#
# <block>:2747:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:56-105: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W23,W22)),(-loves(W22,W23))))
#
# <block>:7:75-143: info: atom does not occur in any rule head:
#   rule(bad,((-takecareof(W24,W24)),(-nicething(W25)),(-dofor(W24,W25))))
#
# <block>:11:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:15:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:19:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:23:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:27:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:31:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:35:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:39:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:43:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:47:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:51:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:2742:13-16: info: operation undefined:
#   (-co)
#
# <block>:2742:105-108: info: operation undefined:
#   (-co)
#
# <block>:2742:221-224: info: operation undefined:
#   (-co)
#
# <block>:2742:343-346: info: operation undefined:
#   (-co)
#
# <block>:2742:411-414: info: operation undefined:
#   (-co)
#
# <block>:2742:527-530: info: operation undefined:
#   (-co)
#
# <block>:2743:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:75-143: info: atom does not occur in any rule head:
#   rule(bad,((-takecareof(W24,W24)),(-nicething(W25)),(-dofor(W24,W25))))
#
# <block>:7:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:11:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:15:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:19:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:23:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:27:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:31:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:35:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:39:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:43:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:47:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:51:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:2738:13-16: info: operation undefined:
#   (-co)
#
# <block>:2738:105-108: info: operation undefined:
#   (-co)
#
# <block>:2738:221-224: info: operation undefined:
#   (-co)
#
# <block>:2738:343-346: info: operation undefined:
#   (-co)
#
# <block>:2738:411-414: info: operation undefined:
#   (-co)
#
# <block>:2738:527-530: info: operation undefined:
#   (-co)
#
# <block>:2739:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:7:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:11:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:15:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:19:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:23:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:27:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:31:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:35:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:39:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:43:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:47:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:51:99-191: info: atom does not occur in any rule head:
#   rule(bad,((-people(f2(W58))),(-mistake(W58)),(-belongsto(W58,f2(W58))),(-admits(f2(W58),W58))))
#
# <block>:2734:13-16: info: operation undefined:
#   (-co)
#
# <block>:2734:105-108: info: operation undefined:
#   (-co)
#
# <block>:2734:221-224: info: operation undefined:
#   (-co)
#
# <block>:2734:343-346: info: operation undefined:
#   (-co)
#
# <block>:2734:411-414: info: operation undefined:
#   (-co)
#
# <block>:2734:527-530: info: operation undefined:
#   (-co)
#
# <block>:2735:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:7:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:11:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:15:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:19:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:23:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:27:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:31:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:35:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:39:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:43:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:47:99-191: info: atom does not occur in any rule head:
#   rule(bad,((-people(f2(W58))),(-mistake(W58)),(-belongsto(W58,f2(W58))),(-admits(f2(W58),W58))))
#
# <block>:51:81-155: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W59,W60)),(-history(W61,W60)),(-caresabout(W59,W61))))
#
# <block>:2730:13-16: info: operation undefined:
#   (-co)
#
# <block>:2730:105-108: info: operation undefined:
#   (-co)
#
# <block>:2730:221-224: info: operation undefined:
#   (-co)
#
# <block>:2730:343-346: info: operation undefined:
#   (-co)
#
# <block>:2730:411-414: info: operation undefined:
#   (-co)
#
# <block>:2730:527-530: info: operation undefined:
#   (-co)
#
# <block>:2731:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:7:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:11:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:15:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:19:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:23:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:27:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:31:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:35:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:39:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:43:99-191: info: atom does not occur in any rule head:
#   rule(bad,((-people(f2(W58))),(-mistake(W58)),(-belongsto(W58,f2(W58))),(-admits(f2(W58),W58))))
#
# <block>:47:81-155: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W59,W60)),(-history(W61,W60)),(-caresabout(W59,W61))))
#
# <block>:51:4-70: info: atom does not occur in any rule head:
#   rule(good,((-thing(V63)),(-phrases(V62,V63)),(-awkwardly(V62,V63))))
#
# <block>:2726:13-16: info: operation undefined:
#   (-co)
#
# <block>:2726:105-108: info: operation undefined:
#   (-co)
#
# <block>:2726:221-224: info: operation undefined:
#   (-co)
#
# <block>:2726:343-346: info: operation undefined:
#   (-co)
#
# <block>:2726:411-414: info: operation undefined:
#   (-co)
#
# <block>:2726:527-530: info: operation undefined:
#   (-co)
#
# <block>:2727:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:7:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:11:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:15:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:19:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:23:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:27:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:31:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:35:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:39:99-191: info: atom does not occur in any rule head:
#   rule(bad,((-people(f2(W58))),(-mistake(W58)),(-belongsto(W58,f2(W58))),(-admits(f2(W58),W58))))
#
# <block>:43:81-155: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W59,W60)),(-history(W61,W60)),(-caresabout(W59,W61))))
#
# <block>:47:4-70: info: atom does not occur in any rule head:
#   rule(good,((-thing(V63)),(-phrases(V62,V63)),(-awkwardly(V62,V63))))
#
# <block>:51:4-93: info: atom does not occur in any rule head:
#   rule(good,((-person(f3(V64))),(-careabout(V64,f3(V64))),(-expecttobeperfect(V64,f3(V64)))))
#
# <block>:2722:13-16: info: operation undefined:
#   (-co)
#
# <block>:2722:105-108: info: operation undefined:
#   (-co)
#
# <block>:2722:221-224: info: operation undefined:
#   (-co)
#
# <block>:2722:343-346: info: operation undefined:
#   (-co)
#
# <block>:2722:411-414: info: operation undefined:
#   (-co)
#
# <block>:2722:527-530: info: operation undefined:
#   (-co)
#
# <block>:2723:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:7:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:11:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:15:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:19:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:23:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:27:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:31:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:35:99-191: info: atom does not occur in any rule head:
#   rule(bad,((-people(f2(W58))),(-mistake(W58)),(-belongsto(W58,f2(W58))),(-admits(f2(W58),W58))))
#
# <block>:39:81-155: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W59,W60)),(-history(W61,W60)),(-caresabout(W59,W61))))
#
# <block>:43:4-70: info: atom does not occur in any rule head:
#   rule(good,((-thing(V63)),(-phrases(V62,V63)),(-awkwardly(V62,V63))))
#
# <block>:47:4-93: info: atom does not occur in any rule head:
#   rule(good,((-person(f3(V64))),(-careabout(V64,f3(V64))),(-expecttobeperfect(V64,f3(V64)))))
#
# <block>:51:4-110: info: atom does not occur in any rule head:
#   rule(good,((-people(V67)),(-familyof(V66,V67)),(-sufferedloss(V66)),(-shares(V67,V66)),(-compassionate(V65))))
#
# <block>:2718:13-16: info: operation undefined:
#   (-co)
#
# <block>:2718:105-108: info: operation undefined:
#   (-co)
#
# <block>:2718:221-224: info: operation undefined:
#   (-co)
#
# <block>:2718:343-346: info: operation undefined:
#   (-co)
#
# <block>:2718:411-414: info: operation undefined:
#   (-co)
#
# <block>:2718:527-530: info: operation undefined:
#   (-co)
#
# <block>:2719:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:7:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:11:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:15:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:19:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:23:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:27:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:31:99-191: info: atom does not occur in any rule head:
#   rule(bad,((-people(f2(W58))),(-mistake(W58)),(-belongsto(W58,f2(W58))),(-admits(f2(W58),W58))))
#
# <block>:35:81-155: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W59,W60)),(-history(W61,W60)),(-caresabout(W59,W61))))
#
# <block>:39:4-70: info: atom does not occur in any rule head:
#   rule(good,((-thing(V63)),(-phrases(V62,V63)),(-awkwardly(V62,V63))))
#
# <block>:43:4-93: info: atom does not occur in any rule head:
#   rule(good,((-person(f3(V64))),(-careabout(V64,f3(V64))),(-expecttobeperfect(V64,f3(V64)))))
#
# <block>:47:4-110: info: atom does not occur in any rule head:
#   rule(good,((-people(V67)),(-familyof(V66,V67)),(-sufferedloss(V66)),(-shares(V67,V66)),(-compassionate(V65))))
#
# <block>:51:4-45: info: atom does not occur in any rule head:
#   rule(good,((-life(V70)),(-makeeasier(V70))))
#
# <block>:2714:13-16: info: operation undefined:
#   (-co)
#
# <block>:2714:105-108: info: operation undefined:
#   (-co)
#
# <block>:2714:221-224: info: operation undefined:
#   (-co)
#
# <block>:2714:343-346: info: operation undefined:
#   (-co)
#
# <block>:2714:411-414: info: operation undefined:
#   (-co)
#
# <block>:2714:527-530: info: operation undefined:
#   (-co)
#
# <block>:2715:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:7:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:11:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:15:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:19:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:23:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:27:99-191: info: atom does not occur in any rule head:
#   rule(bad,((-people(f2(W58))),(-mistake(W58)),(-belongsto(W58,f2(W58))),(-admits(f2(W58),W58))))
#
# <block>:31:81-155: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W59,W60)),(-history(W61,W60)),(-caresabout(W59,W61))))
#
# <block>:35:4-70: info: atom does not occur in any rule head:
#   rule(good,((-thing(V63)),(-phrases(V62,V63)),(-awkwardly(V62,V63))))
#
# <block>:39:4-93: info: atom does not occur in any rule head:
#   rule(good,((-person(f3(V64))),(-careabout(V64,f3(V64))),(-expecttobeperfect(V64,f3(V64)))))
#
# <block>:43:4-110: info: atom does not occur in any rule head:
#   rule(good,((-people(V67)),(-familyof(V66,V67)),(-sufferedloss(V66)),(-shares(V67,V66)),(-compassionate(V65))))
#
# <block>:47:4-45: info: atom does not occur in any rule head:
#   rule(good,((-life(V70)),(-makeeasier(V70))))
#
# <block>:51:77-147: info: atom does not occur in any rule head:
#   rule(bad,((-person(W71)),(-person(f4(W71))),(-debateswith(W71,f4(W71)))))
#
# <block>:2710:13-16: info: operation undefined:
#   (-co)
#
# <block>:2710:105-108: info: operation undefined:
#   (-co)
#
# <block>:2710:221-224: info: operation undefined:
#   (-co)
#
# <block>:2710:343-346: info: operation undefined:
#   (-co)
#
# <block>:2710:411-414: info: operation undefined:
#   (-co)
#
# <block>:2710:527-530: info: operation undefined:
#   (-co)
#
# <block>:2711:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:7:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:11:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:15:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:19:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:23:99-191: info: atom does not occur in any rule head:
#   rule(bad,((-people(f2(W58))),(-mistake(W58)),(-belongsto(W58,f2(W58))),(-admits(f2(W58),W58))))
#
# <block>:27:81-155: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W59,W60)),(-history(W61,W60)),(-caresabout(W59,W61))))
#
# <block>:31:4-70: info: atom does not occur in any rule head:
#   rule(good,((-thing(V63)),(-phrases(V62,V63)),(-awkwardly(V62,V63))))
#
# <block>:35:4-93: info: atom does not occur in any rule head:
#   rule(good,((-person(f3(V64))),(-careabout(V64,f3(V64))),(-expecttobeperfect(V64,f3(V64)))))
#
# <block>:39:4-110: info: atom does not occur in any rule head:
#   rule(good,((-people(V67)),(-familyof(V66,V67)),(-sufferedloss(V66)),(-shares(V67,V66)),(-compassionate(V65))))
#
# <block>:43:4-45: info: atom does not occur in any rule head:
#   rule(good,((-life(V70)),(-makeeasier(V70))))
#
# <block>:47:77-147: info: atom does not occur in any rule head:
#   rule(bad,((-person(W71)),(-person(f4(W71))),(-debateswith(W71,f4(W71)))))
#
# <block>:51:4-44: info: atom does not occur in any rule head:
#   rule(good,((-work(V72)),(-watch(V72,tv))))
#
# <block>:2706:13-16: info: operation undefined:
#   (-co)
#
# <block>:2706:105-108: info: operation undefined:
#   (-co)
#
# <block>:2706:221-224: info: operation undefined:
#   (-co)
#
# <block>:2706:343-346: info: operation undefined:
#   (-co)
#
# <block>:2706:411-414: info: operation undefined:
#   (-co)
#
# <block>:2706:527-530: info: operation undefined:
#   (-co)
#
# <block>:2707:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:7:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:11:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:15:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:19:99-191: info: atom does not occur in any rule head:
#   rule(bad,((-people(f2(W58))),(-mistake(W58)),(-belongsto(W58,f2(W58))),(-admits(f2(W58),W58))))
#
# <block>:23:81-155: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W59,W60)),(-history(W61,W60)),(-caresabout(W59,W61))))
#
# <block>:27:4-70: info: atom does not occur in any rule head:
#   rule(good,((-thing(V63)),(-phrases(V62,V63)),(-awkwardly(V62,V63))))
#
# <block>:31:4-93: info: atom does not occur in any rule head:
#   rule(good,((-person(f3(V64))),(-careabout(V64,f3(V64))),(-expecttobeperfect(V64,f3(V64)))))
#
# <block>:35:4-110: info: atom does not occur in any rule head:
#   rule(good,((-people(V67)),(-familyof(V66,V67)),(-sufferedloss(V66)),(-shares(V67,V66)),(-compassionate(V65))))
#
# <block>:39:4-45: info: atom does not occur in any rule head:
#   rule(good,((-life(V70)),(-makeeasier(V70))))
#
# <block>:43:77-147: info: atom does not occur in any rule head:
#   rule(bad,((-person(W71)),(-person(f4(W71))),(-debateswith(W71,f4(W71)))))
#
# <block>:47:4-44: info: atom does not occur in any rule head:
#   rule(good,((-work(V72)),(-watch(V72,tv))))
#
# <block>:51:4-122: info: atom does not occur in any rule head:
#   rule(good,((-partnerof(V74,V75)),(-exes(V76,V75)),(-boundariesregardingcontactwith(V75,V76)),(-letknow(V74,V75,V76))))
#
# <block>:2702:13-16: info: operation undefined:
#   (-co)
#
# <block>:2702:105-108: info: operation undefined:
#   (-co)
#
# <block>:2702:221-224: info: operation undefined:
#   (-co)
#
# <block>:2702:343-346: info: operation undefined:
#   (-co)
#
# <block>:2702:411-414: info: operation undefined:
#   (-co)
#
# <block>:2702:527-530: info: operation undefined:
#   (-co)
#
# <block>:2703:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))
#
# <block>:7:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:11:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:15:99-191: info: atom does not occur in any rule head:
#   rule(bad,((-people(f2(W58))),(-mistake(W58)),(-belongsto(W58,f2(W58))),(-admits(f2(W58),W58))))
#
# <block>:19:81-155: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W59,W60)),(-history(W61,W60)),(-caresabout(W59,W61))))
#
# <block>:23:4-70: info: atom does not occur in any rule head:
#   rule(good,((-thing(V63)),(-phrases(V62,V63)),(-awkwardly(V62,V63))))
#
# <block>:27:4-93: info: atom does not occur in any rule head:
#   rule(good,((-person(f3(V64))),(-careabout(V64,f3(V64))),(-expecttobeperfect(V64,f3(V64)))))
#
# <block>:31:4-110: info: atom does not occur in any rule head:
#   rule(good,((-people(V67)),(-familyof(V66,V67)),(-sufferedloss(V66)),(-shares(V67,V66)),(-compassionate(V65))))
#
# <block>:35:4-45: info: atom does not occur in any rule head:
#   rule(good,((-life(V70)),(-makeeasier(V70))))
#
# <block>:39:77-147: info: atom does not occur in any rule head:
#   rule(bad,((-person(W71)),(-person(f4(W71))),(-debateswith(W71,f4(W71)))))
#
# <block>:43:4-44: info: atom does not occur in any rule head:
#   rule(good,((-work(V72)),(-watch(V72,tv))))
#
# <block>:47:4-122: info: atom does not occur in any rule head:
#   rule(good,((-partnerof(V74,V75)),(-exes(V76,V75)),(-boundariesregardingcontactwith(V75,V76)),(-letknow(V74,V75,V76))))
#
# <block>:51:4-88: info: atom does not occur in any rule head:
#   rule(good,((-friends(V77,V78)),(-hassignificantother(V78,V79)),(-badmouth(V77,V79))))
#
# <block>:2698:13-16: info: operation undefined:
#   (-co)
#
# <block>:2698:105-108: info: operation undefined:
#   (-co)
#
# <block>:2698:221-224: info: operation undefined:
#   (-co)
#
# <block>:2698:343-346: info: operation undefined:
#   (-co)
#
# <block>:2698:411-414: info: operation undefined:
#   (-co)
#
# <block>:2698:527-530: info: operation undefined:
#   (-co)
#
# <block>:2699:15-18: info: operation undefined:
#   (-co)
#
# <block>:3:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-people(W51)),(-country(W52)),(-belongsto(W52,W51)),(-proudof(W51,W52))))
#
# <block>:7:4-66: info: atom does not occur in any rule head:
#   rule(good,((-partner(V56)),(-feelingsfor(V55,V56)),(-show(V55))))
#
# <block>:11:99-191: info: atom does not occur in any rule head:
#   rule(bad,((-people(f2(W58))),(-mistake(W58)),(-belongsto(W58,f2(W58))),(-admits(f2(W58),W58))))
#
# <block>:15:81-155: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W59,W60)),(-history(W61,W60)),(-caresabout(W59,W61))))
#
# <block>:19:4-70: info: atom does not occur in any rule head:
#   rule(good,((-thing(V63)),(-phrases(V62,V63)),(-awkwardly(V62,V63))))
#
# <block>:23:4-93: info: atom does not occur in any rule head:
#   rule(good,((-person(f3(V64))),(-careabout(V64,f3(V64))),(-expecttobeperfect(V64,f3(V64)))))
#
# <block>:27:4-110: info: atom does not occur in any rule head:
#   rule(good,((-people(V67)),(-familyof(V66,V67)),(-sufferedloss(V66)),(-shares(V67,V66)),(-compassionate(V65))))
#
# <block>:31:4-45: info: atom does not occur in any rule head:
#   rule(good,((-life(V70)),(-makeeasier(V70))))
#
# <block>:35:77-147: info: atom does not occur in any rule head:
#   rule(bad,((-person(W71)),(-person(f4(W71))),(-debateswith(W71,f4(W71)))))
#
# <block>:39:4-44: info: atom does not occur in any rule head:
#   rule(good,((-work(V72)),(-watch(V72,tv))))
#
# <block>:43:4-122: info: atom does not occur in any rule head:
#   rule(good,((-partnerof(V74,V75)),(-exes(V76,V75)),(-boundariesregardingcontactwith(V75,V76)),(-letknow(V74,V75,V76))))
#
# <block>:47:4-88: info: atom does not occur in any rule head:
#   rule(good,((-friends(V77,V78)),(-hassignificantother(V78,V79)),(-badmouth(V77,V79))))
#
# <block>:51:69-131: info: atom does not occur in any rule head:
#   rule(bad,((-plansmarriagewith(W80,W81)),(-stayswith(W80,W81))))
#
# <block>:2694:13-16: info: operation undefined:
#   (-co)
#
# <block>:2694:105-108: info: operation undefined:
#   (-co)
#
# <block>:2694:221-224: info: operation undefined:
#   (-co)
#
# ...
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:83-159: info: atom does not occur in any rule head:
#   rule(bad,((-loves(W103,W104)),(-looksoutforhealthandwellbeingof(W103,W104))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:104-201: info: atom does not occur in any rule head:
#   rule(bad,((-people(W105)),(-people(W106)),(-inrelationship(W105,W106)),(-spendtimewith(W105,W106))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-94: info: atom does not occur in any rule head:
#   rule(good,((-standupfor(V107,V107)),(-demandrespectfrom(V107,V108)),(-closeto(V108,V107))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-66: info: atom does not occur in any rule head:
#   rule(good,((-place(V112)),(-unfamiliar(V112)),(-takenapin(V112))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-72: info: atom does not occur in any rule head:
#   rule(good,((-person(V113)),(-kids(V114)),(-badinfluenceon(V113,V114))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:52-97: info: atom does not occur in any rule head:
#   rule(bad,((-gift(W116)),(-accepts(W115,W116))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:114-221: info: atom does not occur in any rule head:
#   rule(bad,((-breakup(W117,W118)),(-belongsto(W119,W118)),(-window(W120)),(-throwsoutwindow(W117,W119,W120))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:65-123: info: atom does not occur in any rule head:
#   rule(bad,((-findsfunny(W121,W122)),(-laughsat(W121,W122))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:57-107: info: atom does not occur in any rule head:
#   rule(bad,((-laundry(W123)),(-washedregularly(W123))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-92: info: atom does not occur in any rule head:
#   rule(good,((-partnerof(V124,V125)),(-thing(V126)),(-hates(V125,V126)),(-does(V124,V126))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:130-253: info: atom does not occur in any rule head:
#   rule(bad,((-tell(W127,W128)),(-make(W127,W129)),(-fewmonthstolive(W127)),(-familyof(W128,W127)),(-plansfordeath(W129,W127))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-83: info: atom does not occur in any rule head:
#   rule(good,((-parentof(V130,V131)),(-toy(V132)),(-makesputback(V130,V131,V132))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:79-151: info: atom does not occur in any rule head:
#   rule(bad,((-specialoccasion(W134)),(-cleanshaven(W133)),(-for(W133,W134))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-kid(W136)),(-ownership(W135,W136)),(-trustsgutwhendealingwith(W135,W136))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-78: info: atom does not occur in any rule head:
#   rule(good,((-wildanimal(V137)),(-domesticatedfood(V138)),(-feed(V137,V138))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:81-155: info: atom does not occur in any rule head:
#   rule(bad,((-healthissue(W142)),(-has(W141,W142)),(-stayontopof(W141,W142))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:83-159: info: atom does not occur in any rule head:
#   rule(bad,((-person(W143)),(-car(W144)),(-wreck(W143,W144)),(-frustrated(W143))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:91-175: info: atom does not occur in any rule head:
#   rule(bad,((-neighborof(W146,W145)),(-makesdistractingnoise(W146)),(-frustrated(W145))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-85: info: atom does not occur in any rule head:
#   rule(good,((-partnerof(V149,V150)),(-notaround(V150)),(-alwaysloyalto(V149,V150))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-71: info: atom does not occur in any rule head:
#   rule(good,((-kid(V152)),(-parentof(V151,V152)),(-scolds(V151,V152))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-50: info: atom does not occur in any rule head:
#   rule(good,((-candy(V156)),(-brings(V155,V156))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-81: info: atom does not occur in any rule head:
#   rule(good,((-joke(V158)),(-intentionallyconfusefor(V157,f6(V157,V158),V158))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:72-137: info: atom does not occur in any rule head:
#   rule(bad,((-partner(W159,W160)),(-solvesproblemswith(W159,W160))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-44: info: atom does not occur in any rule head:
#   rule(good,(-abusesverbally(V161,V162)))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-78: info: atom does not occur in any rule head:
#   rule(good,((-property(V164)),(-belongsto(V164,V163)),(-damages(V165,V164))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-51: info: atom does not occur in any rule head:
#   rule(good,((-deal(V167)),(-renegeon(V166,V167))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-132: info: atom does not occur in any rule head:
#   rule(good,((-people(f7(V170,V171))),(-thing(V170)),(-beyondcontrolof(V170,f7(V170,V171))),(-criticizes(V171,f7(V170,V171),V170))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-42: info: atom does not occur in any rule head:
#   rule(good,(-wishes(V172,only_child)))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:78-149: info: atom does not occur in any rule head:
#   rule(bad,((-treats(W173,W174,W175)),(-makesrudegesturesat(W174,W173))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:65-123: info: atom does not occur in any rule head:
#   rule(bad,((-people(W176)),(-cultivatelovefor(W176,living))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-95: info: atom does not occur in any rule head:
#   rule(good,((-politicalparty(V177)),(-thing(V178)),(-rude(V178)),(-saysabout(V179,V178,V177))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:102-197: info: atom does not occur in any rule head:
#   rule(bad,((-car(W181)),(-belongsto(W181,W180)),(-choose(W180,W182)),(-allowin(W180,W181,W182))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-69: info: atom does not occur in any rule head:
#   rule(good,((-people(V183)),(-tailgating(V184)),(-stops(V183,V184))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:128-249: info: atom does not occur in any rule head:
#   rule(bad,((-thing(W185)),(-property(f8(W185,W186))),(-belongsto(f8(W185,W186),W186)),(-throwsat(W186,W185,f8(W185,W186)))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-75: info: atom does not occur in any rule head:
#   rule(good,((-death(V188)),(-supports(V189,V187)),(-familyof(V187,V188))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:70-133: info: atom does not occur in any rule head:
#   rule(bad,((-behavior(W191)),(-bad(W191)),(-confronts(W190,W191))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-80: info: atom does not occur in any rule head:
#   rule(good,((-rabbit(V192)),(-outside(V192,V193)),(-cold(V193)),(-winter(V193))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:54-101: info: atom does not occur in any rule head:
#   rule(bad,((-thing(W194)),(-passdown(W195,W194))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:57-107: info: atom does not occur in any rule head:
#   rule(bad,((-thing(W197)),(-thinksabout(W196,W197))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-61: info: atom does not occur in any rule head:
#   rule(good,((-girl(V198)),(-girl(V199)),(-dates(V198,V199))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-116: info: atom does not occur in any rule head:
#   rule(good,((-liveswith(V202,V203)),(-people(V203)),(-chore(f9(V202,V203))),(-leavesfor(V202,V203,f9(V202,V203)))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-57: info: atom does not occur in any rule head:
#   rule(good,(-makesajokeabout(V0,sexual_orientation)))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:4-86: info: atom does not occur in any rule head:
#   rule(good,((-person(V1)),(-personalspace(V2)),(-belongsto(V2,V3)),(-invades(V1,V2))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:61-115: info: atom does not occur in any rule head:
#   rule(bad,((-job(W4)),(-wellpaying(W4)),(-successful(W4))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:108-209: info: atom does not occur in any rule head:
#   rule(bad,((-person(W5)),(-communities(f0(W5))),(-feelslikehastobepartof(W5,f0(W5))),(-multiple(f0(W5)))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:74-141: info: atom does not occur in any rule head:
#   rule(bad,((-people(W9)),(-love(W9,W8)),(-thing(W8)),(-pursue(W9,W8))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:56-105: info: atom does not occur in any rule head:
#   rule(bad,((-sad(W11)),(-tellstoregulate(W10,W11))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:8:88-169: info: atom does not occur in any rule head:
#   rule(bad,((-company(W12)),(-people(W13)),(-hasdisability(W13)),(-catersto(W12,W13))))
#
# <block>:3:4-69: info: atom does not occur in any rule head:
#   rule(good,((-teacher(V124)),(-student(V125)),(-bullies(V124,V125))))
#
# <block>:3:4-56: info: atom does not occur in any rule head:
#   rule(good,((-familyof(V4,V3)),(-askstoomuch(V3,V4))))
#
# <block>:7:74-141: info: atom does not occur in any rule head:
#   rule(bad,((-goesshopping(W5)),(-people(W6)),(-new(W6)),(-meet(W5,W6))))
#
# <block>:11:80-153: info: atom does not occur in any rule head:
#   rule(bad,((-firstpaycheck(W8)),(-belongsto(W8,W7)),(-excitedabout(W7,W8))))
#
# <block>:15:71-135: info: atom does not occur in any rule head:
#   rule(bad,((-safetoeat(W11)),(-servesto(W9,W10,W11)),(-food(W11))))
#
# <block>:19:4-73: info: atom does not occur in any rule head:
#   rule(good,((-sees(V12,V13)),(-advantageinlife(V13)),(-takes(V12,V13))))
#
# <block>:23:4-92: info: atom does not occur in any rule head:
#   rule(good,((-friends(V14,V15)),(-hassignificantother(V15,V16)),(-triestosteal(V14,V16))))
#
# <block>:27:4-84: info: atom does not occur in any rule head:
#   rule(good,((-wantstolearn(V19,drive)),(-freedrivinglesson(V20)),(-gets(V19,V20))))
#
# <block>:31:4-35: info: atom does not occur in any rule head:
#   rule(good,(-livesin(V21,van)))
#
# <block>:35:56-105: info: atom does not occur in any rule head:
#   rule(bad,((-familyof(W23,W22)),(-loves(W22,W23))))
#
# <block>:39:75-143: info: atom does not occur in any rule head:
#   rule(bad,((-takecareof(W24,W24)),(-nicething(W25)),(-dofor(W24,W25))))
#
# <block>:43:97-187: info: atom does not occur in any rule head:
#   rule(bad,((-employer(W26)),(-program(W27)),(-belongsto(W27,W26)),(-hasdoubtsabout(you,W27))))
#
# <block>:47:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-tourguide(W28)),(-hires(W29,W28)),(-newplaces(W30)),(-learnabout(W29,W30))))
#
# <block>:51:84-161: info: atom does not occur in any rule head:
#   rule(bad,((-buddies(W31,W32)),(-outdoors(W33)),(-gocampingwith(W31,W32,W33))))
#
# <block>:55:92-177: info: atom does not occur in any rule head:
#   rule(bad,((-people(W34)),(-people(W36)),(-ageof(W35,W36)),(-datebasedon(W34,W36,W35))))
#
# <block>:59:105-203: info: atom does not occur in any rule head:
#   rule(bad,((-people(W38)),(-friends(W39,W38)),(-relationship(W40,W39)),(-rootforsuccessof(W38,W40))))
#
# <block>:63:4-72: info: atom does not occur in any rule head:
#   rule(good,((-workson(V42,amazon_mechanical_turk)),(-frustrated(V42))))
#
# <block>:67:73-139: info: atom does not occur in any rule head:
#   rule(bad,((-healthscare(W43)),(-belongsto(W43,W44)),(-averted(W43))))
#
# <block>:71:76-145: info: atom does not occur in any rule head:
#   rule(bad,((-friend(W45,W46)),(-quidsmoking(W46)),(-supports(W45,W46))))
#
# <block>:75:4-101: info: atom does not occur in any rule head:
#   rule(good,((-people(V47)),(-raceattribute(V48,f1(V47,V48))),(-singlesoutbasedon(V47,f1(V47,V48)))))
#
# <block>:79:86-165: info: atom does not occur in any rule head:
#   rule(bad,((-anxietyof(W49,W50)),(-interfereswithdailylife(W50)),(-getshelp(W50))))

# %%
print(str(sett))
# Out:
# ---------------------------
# % (¬Co-workerOf(v180, v179) ∨ ¬WeddingOf(v181, v179) ∨ ¬InvitesTo(v179, v180, v181) ∨ evaluation(BAD))
# 6{rule(bad,(-co-workerof(v180, v179), -weddingof(v181, v179), -invitesto(v179, v180, v181))); rule(bad,(-co-workerof(v180, v179), -invitesto(v179, v180, v181), -weddingof(v181, v179))); rule(bad,(-weddingof(v181, v179), -co-workerof(v180, v179), -invitesto(v179, v180, v181))); rule(bad,(-weddingof(v181, v179), -invitesto(v179, v180, v181), -co-workerof(v180, v179))); rule(bad,(-invitesto(v179, v180, v181), -co-workerof(v180, v179), -weddingof(v181, v179))); rule(bad,(-invitesto(v179, v180, v181), -weddingof(v181, v179), -co-workerof(v180, v179)))}6.
# :- rule(good,(-co-workerof(V180, V179), -weddingof(V181, V179), -invitesto(V179, V180, V181))), rule(bad,(-co-workerof(W180, W179), -weddingof(W181, W179), -invitesto(W179, W180, W181))).
# %---CLAUSE---
# ---------------------------
# % (¬Partner(v184, v185) ∨ ¬LargePurchase(v186) ∨ ¬InvolvedInProcessOf(v184, v186) ∨ ¬Partner(v185, v184) ∨ ¬LargePurchase(v186) ∨ ¬InvolvedInProcessOf(v185, v186) ∨ evaluation(GOOD))
# 720{rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v184, v186), -partner(v185, v184), -largepurchase(v186), -involvedinprocessof(v185, v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v184, v186), -partner(v185, v184), -involvedinprocessof(v185, v186), -largepurchase(v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v184, v186), -largepurchase(v186), -partner(v185, v184), -involvedinprocessof(v185, v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v184, v186), -largepurchase(v186), -involvedinprocessof(v185, v186), -partner(v185, v184))); rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v184, v186), -involvedinprocessof(v185, v186), -partner(v185, v184), -largepurchase(v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v184, v186), -involvedinprocessof(v185, v186), -largepurchase(v186), -partner(v185, v184))); rule(good,(-partner(v184, v185), -largepurchase(v186), -partner(v185, v184), -involvedinprocessof(v184, v186), -largepurchase(v186), -involvedinprocessof(v185, v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -partner(v185, v184), -involvedinprocessof(v184, v186), -involvedinprocessof(v185, v186), -largepurchase(v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -partner(v185, v184), -largepurchase(v186), -involvedinprocessof(v184, v186), -involvedinprocessof(v185, v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -partner(v185, v184), -largepurchase(v186), -involvedinprocessof(v185, v186), -involvedinprocessof(v184, v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -partner(v185, v184), -involvedinprocessof(v185, v186), -involvedinprocessof(v184, v186), -largepurchase(v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -partner(v185, v184), -involvedinprocessof(v185, v186), -largepurchase(v186), -involvedinprocessof(v184, v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -largepurchase(v186), -involvedinprocessof(v184, v186), -partner(v185, v184), -involvedinprocessof(v185, v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -largepurchase(v186), -involvedinprocessof(v184, v186), -involvedinprocessof(v185, v186), -partner(v185, v184))); rule(good,(-partner(v184, v185), -largepurchase(v186), -largepurchase(v186), -partner(v185, v184), -involvedinprocessof(v184, v186), -involvedinprocessof(v185, v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -largepurchase(v186), -partner(v185, v184), -involvedinprocessof(v185, v186), -involvedinprocessof(v184, v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -largepurchase(v186), -involvedinprocessof(v185, v186), -involvedinprocessof(v184, v186), -partner(v185, v184))); rule(good,(-partner(v184, v185), -largepurchase(v186), -largepurchase(v186), -involvedinprocessof(v185, v186), -partner(v185, v184), -involvedinprocessof(v184, v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v185, v186), -involvedinprocessof(v184, v186), -partner(v185, v184), -largepurchase(v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v185, v186), -involvedinprocessof(v184, v186), -largepurchase(v186), -partner(v185, v184))); rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v185, v186), -partner(v185, v184), -involvedinprocessof(v184, v186), -largepurchase(v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v185, v186), -partner(v185, v184), -largepurchase(v186), -involvedinprocessof(v184, v186))); rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v185, v186), -largepurchase(v186), -involvedinprocessof(v184, v186), -partner(v185, v184))); rule(good,(-partner(v184, v185), -largepurchase(v186), -involvedinprocessof(v185, v186), -largepurchase(v186) ...
# :- rule(good,(-partner(V184, V185), -largepurchase(V186), -involvedinprocessof(V184, V186), -partner(V185, V184), -largepurchase(V186), -involvedinprocessof(V185, V186))), rule(bad,(-partner(W184, W185), -largepurchase(W186), -involvedinprocessof(W184, W186), -partner(W185, W184), -largepurchase(W186), -involvedinprocessof(W185, W186))).
# %---CLAUSE---
# ---------------------------
# % (¬Teacher(v124) ∨ ¬Student(v125) ∨ ¬Bullies(v124, v125) ∨ evaluation(BAD))
# 6{rule(bad,(-teacher(v124), -student(v125), -bullies(v124, v125))); rule(bad,(-teacher(v124), -bullies(v124, v125), -student(v125))); rule(bad,(-student(v125), -teacher(v124), -bullies(v124, v125))); rule(bad,(-student(v125), -bullies(v124, v125), -teacher(v124))); rule(bad,(-bullies(v124, v125), -teacher(v124), -student(v125))); rule(bad,(-bullies(v124, v125), -student(v125), -teacher(v124)))}6.
# :- rule(good,(-teacher(V124), -student(V125), -bullies(V124, V125))), rule(bad,(-teacher(W124), -student(W125), -bullies(W124, W125))).
# %---CLAUSE---
#
# % (¬Teacher(v68) ∨ ¬Student(v69) ∨ ¬Bullies(v68, v69) ∨ evaluation(GOOD))
# 6{rule(good,(-teacher(v68), -student(v69), -bullies(v68, v69))); rule(good,(-teacher(v68), -bullies(v68, v69), -student(v69))); rule(good,(-student(v69), -teacher(v68), -bullies(v68, v69))); rule(good,(-student(v69), -bullies(v68, v69), -teacher(v68))); rule(good,(-bullies(v68, v69), -teacher(v68), -student(v69))); rule(good,(-bullies(v68, v69), -student(v69), -teacher(v68)))}6.
# :- rule(good,(-teacher(V68), -student(V69), -bullies(V68, V69))), rule(bad,(-teacher(W68), -student(W69), -bullies(W68, W69))).
# %---CLAUSE---
# ---------------------------

# %% [markdown]
# ## Sentiment analysis
#
# The following cell will first extract the labels of each FOL from the manually encoded FOLs from the file ``annotated-encodings.tsv``. The labeles are found based on whether or not the manual encoding use the word "GOOD" or "BAD" in the evaluation part.
#
# Using the same technique, we extract the labels of each FOL from the automatically encoded FOLs fromthe same file.
#
# We then apply a fine-tuned DistilBERT sentiment analysis model on the norms from the same file. The SA labels are compared to the correct labels from the manual encoding in a cross table to give an incidcation of how well the SA model is able to predict the labels. The labels from the automatic encoding is also compared to the correct labels in a cross table to give an indication of how well the encoding system is able to predict labels.

# %%
from transformers import pipeline

df = pd.read_csv('results/annotated-encodings.tsv', sep='\t', header=0)

trans = []
adjust = []
for index, row in df.iterrows():
    i = (row['manual_fol_encoding'].find('→'))
    if 'GOOD' in row['manual_fol_encoding'][i:]:
        trans.append(1)
    elif 'BAD' in row['manual_fol_encoding'][i:]:
        trans.append(0)
    else:
        trans.append(-1)
        
df = df.assign(manual_fol_encoding_sentiment=trans)

for index, row in df.iterrows():
    i = (row['automated_fol_encoding'].find('→'))
    if 'GOOD' in row['automated_fol_encoding'][i:]:
        adjust.append(1)
    elif 'BAD' in row['automated_fol_encoding'][i:]:
        adjust.append(0)
    else:
        adjust.append(-1)
    
df = df.assign(automated_fol_encoding_sentiment=adjust)

sdf = df.copy()
sdf = sdf.filter(['num', 'input_sequence', 'manual_fol_encoding', 'automated_fol_encoding', 'automated_fol_encoding-eval', 'manual_fol_encoding_sentiment', 'automated_fol_encoding_sentiment'])
sentences = sdf['input_sequence'].tolist()
sentiment_df = sdf.filter(['num', 'manual_fol_encoding_sentiment', 'automated_fol_encoding_sentiment'])

sentiment_pipeline = pipeline(model="emmabjor/finetuning-sentiment-model")

data = sentences
finetuned = sentiment_pipeline(data)

sentiment = []
for el in finetuned:
    if el['label'] == "LABEL_1":
        sentiment.append(1)
    elif el['label'] == "LABEL_0":
        sentiment.append(0)
    else:
        sentiment.append(-1)
        
sentiment_df = sentiment_df.assign(finetuned_sentiment = sentiment)

translation_sentiment_array = sentiment_df['manual_fol_encoding_sentiment'].to_numpy()
adjustment_sentiment_array = sentiment_df['automated_fol_encoding_sentiment'].to_numpy()
sentiment_model_array = sentiment_df['finetuned_sentiment'].to_numpy()
finetuned_ct = pd.crosstab(translation_sentiment_array, sentiment_model_array, rownames=['Manual encoding Sentiment'], colnames=['Fine Tuned Sentiment'], normalize='index')
print(finetuned_ct)
print()
finetuned_ct_adjusted = pd.crosstab(translation_sentiment_array, adjustment_sentiment_array, rownames=['Manual encoding Sentiment'], colnames=['Automatic encoding Sentiment'], normalize='index')
print(finetuned_ct_adjusted)
